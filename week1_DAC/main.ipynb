# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive/Work/Study/Self-supervised learning
# Out:
# /content/drive/MyDrive/Work/Study/Self-supervised learning

# %%
import torch
from conv import MNISTNetwork
from trainer import Trainer
from dataloader import retrieve_mnist

# %%
USE_CUDA = torch.cuda.is_available()
print(USE_CUDA)

device = torch.device('cuda:0' if USE_CUDA else 'cpu')
print('학습을 진행하는 기기:',device)
# Out:
# True
# 학습을 진행하는 기기: cuda:0

# %%
batch_size = 128
epoch = 50
trainer = Trainer(MNISTNetwork, epoch=epoch, device=device)

# %%
data = retrieve_mnist(batch_size=batch_size)
trainer.train(data)
# Out:
# Epoch: 0, Iteration:0, loss: 13.047938346862793
# Epoch: 0, Iteration:100, loss: 2.094674587249756
# Epoch: 0, Iteration:200, loss: 1.9155097007751465
# Epoch: 0, Iteration:300, loss: 1.8563132286071777
# Epoch: 0, Iteration:400, loss: 1.8902697563171387
# Epoch: 0, Iteration:500, loss: 1.8329684734344482
# Epoch: 1, Iteration:0, loss: 1.8022912740707397
# Epoch: 1, Iteration:100, loss: 1.747348427772522
# Epoch: 1, Iteration:200, loss: 1.6708645820617676
# Epoch: 1, Iteration:300, loss: 1.6620084047317505
# Epoch: 1, Iteration:400, loss: 1.6384000778198242
# Epoch: 1, Iteration:500, loss: 1.6384000778198242
# Epoch: 2, Iteration:0, loss: 1.6384000778198242
# Epoch: 2, Iteration:100, loss: 1.6384000778198242
# Epoch: 2, Iteration:200, loss: 1.6384000778198242
# Epoch: 2, Iteration:300, loss: 1.6384000778198242
# Epoch: 2, Iteration:400, loss: 1.6384000778198242
# Epoch: 2, Iteration:500, loss: 1.6384000778198242
# Epoch: 3, Iteration:0, loss: 1.6384000778198242
# ...
